# %% [markdown]
# # Hello World!
#
#
# ### This is Coursera IBM Applied Data Science Capstone Week 3 Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto
#
# In this assignment we should explore and cluster the neighborhoods in Toronto by scrapping postal code of Toronto using Wikipedia data.
#
#
#
# ## 01- Preparing the Dataframe:

# %%
import sys
# !{sys.executable} -m pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 7.1 MB/s  eta 0:00:01
# ...

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing dataframe libraries
import numpy as np 
import pandas as pd 
import requests 
from bs4 import BeautifulSoup

# %%
# Scrapping postal code of Canda
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
dataSource = requests.get(url).text
soup = BeautifulSoup(dataSource, 'xml')
table=soup.find('table')
column_names = ['Postalcode','Borough','Neighborhood']
df = pd.DataFrame(columns = column_names)

# %%
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df)] = row_data
        
        
df.head()
# Out:
#   Postalcode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Cliening data by removing 'Not assigned' from Borough column
df1 = df.dropna()
empty = 'Not assigned'
df1 = df1[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]

df1.head()
# Out:
#   Postalcode           Borough                                 Neighborhood
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

df2.head()
# Out:
#   Postalcode       Borough                            Neighborhood
# 0        M1A  Not assigned                            Not assigned
# 1        M1B   Scarborough                          Malvern, Rouge
# 2        M1C   Scarborough  Rouge Hill, Port Union, Highland Creek
# 3        M1E   Scarborough       Guildwood, Morningside, West Hill
# 4        M1G   Scarborough                                  Woburn

# %% [markdown]
# ## 02- Getting Tornoto neighborhood atitude and longitude coordinates:

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import geocoder # import geocoder
import requests 
from bs4 import BeautifulSoup

# %%
List_url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(List_url).text

soup = BeautifulSoup(source, 'xml')

# %%
table=soup.find('table')
column_names=['Postalcode','Borough','Neighbourhood']
df3 = pd.DataFrame(columns=column_names)

for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df3)] = row_data
        

df3.head()
# Out:
# Empty DataFrame
# Columns: [Postalcode, Borough, Neighbourhood]
# Index: []

# %%
df4=df.groupby('Postalcode')['Neighbourhood'].apply(lambda x: "%s" % ', '.join(x))
df4=temp_df.reset_index(drop=False)
df4.rename(columns={'Neighbourhood':'Neighbourhood_joined'},inplace=True)

# %%
TorontoNeib_df = pd.merge(df, df4, on='Postalcode')

TorontoNeib_df.drop(['Neighbourhood'],axis=1,inplace=True)

TorontoNeib_df.drop_duplicates(inplace=True)

TorontoNeib_df.rename(columns={'Neighbourhood_joined':'Neighbourhood'},inplace=True)
TorontoNeib_df.head()
# Out:
#   Postalcode           Borough  index  \
# 0        M3A        North York     25
# 1        M4A        North York     34
# 2        M5A  Downtown Toronto     53
# 3        M6A        North York     71
# 4        M7A  Downtown Toronto     85
#
#                                  Neighbourhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %%
TorontoNeib_df.shape
# Out:
# (104, 4)

# %%
def LatLong(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude,longitude

# %%
TorontoNeib_df=pd.read_csv('http://cocl.us/Geospatial_data')
TorontoNeib_df.rename(columns={'Postal Code':'Postalcode'},inplace=True)
Merged_df = pd.merge(geo_df, df_merge, on='Postalcode')
NeibLoc=merged_df[['Postalcode','Borough','Neighbourhood','Latitude','Longitude']]

NeibLoc.head()
# Out:
#   Postalcode      Borough                           Neighbourhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476
